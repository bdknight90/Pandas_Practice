# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

poke_data = pd.read_csv('Documents/pokemon.csv', index_col=None, na_values=['NA'])

# %%
poke_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...       percentage_male  \
# 0             2.0            1.0      ...                  88.1
# ...

# %%
pokebasics = poke_data[['name','type1','type2','attack','sp_attack','defense','sp_defense','speed']]

# %%
poketype = pokebasics[['name','type1','type2']]

# %%
poketype[(poketype['type1']=='bug') & (poketype['type2']=='poison')]
# Out:
#            name type1   type2
# 12       Weedle   bug  poison
# 13       Kakuna   bug  poison
# 14     Beedrill   bug  poison
# 47      Venonat   bug  poison
# 48     Venomoth   bug  poison
# 166    Spinarak   bug  poison
# 167     Ariados   bug  poison
# 268      Dustox   bug  poison
# 542    Venipede   bug  poison
# 543  Whirlipede   bug  poison
# 544   Scolipede   bug  poison

# %%
poketype[(poketype['type1'].isin(['bug','poison'])) & (poketype['type2'].isin(['bug','poison']))]
# Out:
#            name   type1   type2
# 12       Weedle     bug  poison
# 13       Kakuna     bug  poison
# 14     Beedrill     bug  poison
# 47      Venonat     bug  poison
# 48     Venomoth     bug  poison
# 87       Grimer  poison  poison
# 88          Muk  poison  poison
# 166    Spinarak     bug  poison
# 167     Ariados     bug  poison
# 268      Dustox     bug  poison
# 450     Skorupi  poison     bug
# 542    Venipede     bug  poison
# 543  Whirlipede     bug  poison
# 544   Scolipede     bug  poison

# %%
poketype2 = poketype.copy()

# %%
#Pokemon with no dual types are doubling types (Grimer, Muk, Charmander, etc...), 
#let's fix that by making the type2 Null if they match type1

poketype2.loc[poketype2['type1']==poketype2['type2'],'type2'] = None

# %%
pokebasics[pokebasics['type1']=='bug'].sort_values(by='speed')
# Out:
#            name type1     type2  attack  sp_attack  defense  sp_defense  speed
# 212     Shuckle   bug      rock      10         10      230         230      5
# 203      Pineco   bug       NaN      65         35       90          35     15
# 265     Silcoon   bug       NaN      35         25       55          25     15
# 267     Cascoon   bug       NaN      35         25       55          25     15
# 264     Wurmple   bug       NaN      45         20       35          30     20
# 588  Escavalier   bug     steel     135         60      105         105     20
# 615     Shelmet   bug       NaN      40         40       85          65     25
# 400   Kricketot   bug       NaN      25         25       41          41     25
# 45        Paras   bug     grass      70         45       55          55     25
# 664      Spewpa   bug       NaN      22         27       60          30     29
# 10      Metapod   bug       NaN      20         25       55          25     30
# ...

# %%
legendata = legendata[['pokedex_number','name','type1','type2','attack','defense','sp_attack','sp_defense','speed']]

# %%
legendata[legendata['type1']=='bug']
# Out:
#      pokedex_number       name type1     type2  attack  defense  sp_attack  \
# 648             649   Genesect   bug     steel     120       95        120
# 793             794   Buzzwole   bug  fighting     139      139         53
# 794             795  Pheromosa   bug  fighting     137       37        137
#
#      sp_defense  speed
# 648          95     99
# 793          53     79
# 794          37    151
